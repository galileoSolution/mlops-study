# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('green_tripdata_2021-01.parquet')
df_val = read_dataframe('green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715204122913

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.001
    max_iter=500

    mlflow.log_param("alpha", alpha)
    mlflow.log_param("max_iter", max_iter)

    lr = Lasso(alpha,max_iter= max_iter)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %% [markdown]
# ###

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
scope.int(hp.quniform('max_depth', 4, 100, 1))

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [14:26:20] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:7.14199
# [1]	validation-rmse:6.66080
# [2]	validation-rmse:6.62573
# [3]	validation-rmse:6.60526
# [4]	validation-rmse:6.59262
# [5]	validation-rmse:6.58527
# [6]	validation-rmse:6.57823
# [7]	validation-rmse:6.57354
# [8]	validation-rmse:6.56588
# [9]	validation-rmse:6.55801
# [10]	validation-rmse:6.55155
# [11]	validation-rmse:6.54464
# [12]	validation-rmse:6.53915
# [13]	validation-rmse:6.53385
# [14]	validation-rmse:6.52789
# [15]	validation-rmse:6.52660
# [16]	validation-rmse:6.52300
# [17]	validation-rmse:6.52088
# [18]	validation-rmse:6.51937
# [19]	validation-rmse:6.51679
# [20]	validation-rmse:6.50969
# [21]	validation-rmse:6.50949
# [22]	validation-rmse:6.50703
# [23]	validation-rmse:6.49799
# [24]	validation-rmse:6.49498
# [25]	validation-rmse:6.49160
# [26]	validation-rmse:6.49060
# [27]	validation-rmse:6.49041
# [28]	validation-rmse:6.49044
# [29]	validation-rmse:6.49068
# [30]	validation-rmse:6.48812
# [31]	validation-rmse:6.48739
# [32]	validation-rmse:6.49004
# [33]	validation-rmse:6.48927
# [34]	validation-rmse:6.48481
# [35]	validation-rmse:6.48291
# [36]	validation-rmse:6.48239
# [37]	validation-rmse:6.48289
# [38]	validation-rmse:6.47938
# [39]	validation-rmse:6.48764
# [40]	validation-rmse:6.49088
# [41]	validation-rmse:6.49185
# [42]	validation-rmse:6.49223
# [43]	validation-rmse:6.48986
# [44]	validation-rmse:6.48879
# [45]	validation-rmse:6.48937
# [46]	validation-rmse:6.48852
# [47]	validation-rmse:6.48791
# [48]	validation-rmse:6.49198
# [49]	validation-rmse:6.49255
# [50]	validation-rmse:6.49319
# [51]	validation-rmse:6.49188
# [52]	validation-rmse:6.49146
# [53]	validation-rmse:6.49134
# [54]	validation-rmse:6.49123
# [55]	validation-rmse:6.49117
# [56]	validation-rmse:6.49209
# [57]	validation-rmse:6.49213
# [58]	validation-rmse:6.49129
# [59]	validation-rmse:6.49022
# [60]	validation-rmse:6.49064
# [61]	validation-rmse:6.49123
# [62]	validation-rmse:6.49160
# [63]	validation-rmse:6.49261
# [64]	validation-rmse:6.49258
# [65]	validation-rmse:6.49964
# [66]	validation-rmse:6.50055
# [67]	validation-rmse:6.50103
# [68]	validation-rmse:6.50069
# [69]	validation-rmse:6.50046
# [70]	validation-rmse:6.50130
# [71]	validation-rmse:6.50553
# [72]	validation-rmse:6.50572
# [73]	validation-rmse:6.50749
# [74]	validation-rmse:6.50763
# [75]	validation-rmse:6.50956
# [76]	validation-rmse:6.50946
# [77]	validation-rmse:6.51258
# [78]	validation-rmse:6.51349
# [79]	validation-rmse:6.51369
# [80]	validation-rmse:6.51357
# [81]	validation-rmse:6.51324
# [82]	validation-rmse:6.51308
# [83]	validation-rmse:6.51476
# [84]	validation-rmse:6.51459
# [85]	validation-rmse:6.51514
# [86]	validation-rmse:6.51612
# [87]	validation-rmse:6.51577
# [88]	validation-rmse:6.51522
# [14:26:27] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.10180
# [1]	validation-rmse:7.10793
# [2]	validation-rmse:6.80504
# [3]	validation-rmse:6.73439
# [4]	validation-rmse:6.71301
# [5]	validation-rmse:6.70345
# [6]	validation-rmse:6.70126
# [7]	validation-rmse:6.69223
# [8]	validation-rmse:6.68904
# [9]	validation-rmse:6.68542
# [10]	validation-rmse:6.68246
# [11]	validation-rmse:6.67755
# [12]	validation-rmse:6.67318
# [13]	validation-rmse:6.67129
# [14]	validation-rmse:6.66867
# [15]	validation-rmse:6.66558
# [16]	validation-rmse:6.66257
# [17]	validation-rmse:6.65927
# [18]	validation-rmse:6.65864
# [19]	validation-rmse:6.65480
# [20]	validation-rmse:6.65529
# [21]	validation-rmse:6.65352
# [22]	validation-rmse:6.65051
# [23]	validation-rmse:6.64978
# [24]	validation-rmse:6.64688
# [25]	validation-rmse:6.64494
# [26]	validation-rmse:6.64343
# [27]	validation-rmse:6.64061
# [28]	validation-rmse:6.63824
# [29]	validation-rmse:6.63546
# [30]	validation-rmse:6.63343
# [31]	validation-rmse:6.62825
# [32]	validation-rmse:6.62489
# [33]	validation-rmse:6.62285
# [34]	validation-rmse:6.61969
# [35]	validation-rmse:6.61540
# [36]	validation-rmse:6.61394
# [37]	validation-rmse:6.61148
# [38]	validation-rmse:6.60967
# [39]	validation-rmse:6.60800
# [40]	validation-rmse:6.60482
# [41]	validation-rmse:6.60142
# [42]	validation-rmse:6.59842
# [43]	validation-rmse:6.59486
# [44]	validation-rmse:6.59174
# [45]	validation-rmse:6.58930
# [46]	validation-rmse:6.58831
# [47]	validation-rmse:6.58399
# [48]	validation-rmse:6.58073
# [49]	validation-rmse:6.57989
# [50]	validation-rmse:6.57625
# [51]	validation-rmse:6.57528
# [52]	validation-rmse:6.57288
# [53]	validation-rmse:6.57230
# [54]	validation-rmse:6.57245
# [55]	validation-rmse:6.57019
# [56]	validation-rmse:6.56865
# [57]	validation-rmse:6.56685
# [58]	validation-rmse:6.56623
# [59]	validation-rmse:6.56519
# [60]	validation-rmse:6.56415
# [61]	validation-rmse:6.56193
# [62]	validation-rmse:6.56183
# [63]	validation-rmse:6.56006
# [64]	validation-rmse:6.55931
# [65]	validation-rmse:6.55779
# [66]	validation-rmse:6.55757
# [67]	validation-rmse:6.55447
# [68]	validation-rmse:6.55383
# [69]	validation-rmse:6.55308
# [70]	validation-rmse:6.55187
# [71]	validation-rmse:6.55104
# [72]	validation-rmse:6.54928
# [73]	validation-rmse:6.54851
# [74]	validation-rmse:6.54712
# [75]	validation-rmse:6.54521
# [76]	validation-rmse:6.54483
# [77]	validation-rmse:6.54386
# [78]	validation-rmse:6.54298
# [79]	validation-rmse:6.54121
# [80]	validation-rmse:6.54073
# [81]	validation-rmse:6.53986
# [82]	validation-rmse:6.53900
# [83]	validation-rmse:6.53843
# [84]	validation-rmse:6.53662
# [85]	validation-rmse:6.53599
# [86]	validation-rmse:6.53514
# [87]	validation-rmse:6.53436
# [88]	validation-rmse:6.53439
# [89]	validation-rmse:6.53201
# [90]	validation-rmse:6.53087
# [91]	validation-rmse:6.52923
# [92]	validation-rmse:6.52814
# [93]	validation-rmse:6.52651
# [94]	validation-rmse:6.52570
# [95]	validation-rmse:6.52367
# [96]	validation-rmse:6.52013
# [97]	validation-rmse:6.51886
# [98]	validation-rmse:6.51773
# [99]	validation-rmse:6.51701
# [100]	validation-rmse:6.51506
# [101]	validation-rmse:6.51540
# [102]	validation-rmse:6.51347
# [103]	validation-rmse:6.51235
# [104]	validation-rmse:6.51017
# [105]	validation-rmse:6.50979
# [106]	validation-rmse:6.50714
# [107]	validation-rmse:6.50473
# [108]	validation-rmse:6.50322
# [109]	validation-rmse:6.50290
# [110]	validation-rmse:6.50131
# [111]	validation-rmse:6.50126
# [112]	validation-rmse:6.50024
# [113]	validation-rmse:6.49880
# [114]	validation-rmse:6.50153
# [115]	validation-rmse:6.50126
# [116]	validation-rmse:6.49761
# [117]	validation-rmse:6.49628
# [118]	validation-rmse:6.49522
# [119]	validation-rmse:6.49388
# [120]	validation-rmse:6.49234
# [121]	validation-rmse:6.49235
# [122]	validation-rmse:6.49180
# [123]	validation-rmse:6.49195
# [124]	validation-rmse:6.49011
# [125]	validation-rmse:6.48930
# [126]	validation-rmse:6.48872
# [127]	validation-rmse:6.48802
# [128]	validation-rmse:6.48747
# [129]	validation-rmse:6.48713
# [130]	validation-rmse:6.48586
# [131]	validation-rmse:6.48456
# [132]	validation-rmse:6.48218
# [133]	validation-rmse:6.48046
# [134]	validation-rmse:6.47915
# [135]	validation-rmse:6.47679
# [136]	validation-rmse:6.47593
# [137]	validation-rmse:6.47542
# [138]	validation-rmse:6.47491
# [139]	validation-rmse:6.47337
# [140]	validation-rmse:6.47362
# [141]	validation-rmse:6.47287
# [142]	validation-rmse:6.47189
# [143]	validation-rmse:6.47076
# [144]	validation-rmse:6.47090
# [145]	validation-rmse:6.46983
# [146]	validation-rmse:6.46885
# [147]	validation-rmse:6.46785
# [148]	validation-rmse:6.46686
# [149]	validation-rmse:6.46550
# [150]	validation-rmse:6.46479
# [151]	validation-rmse:6.46478
# [152]	validation-rmse:6.46529
# [153]	validation-rmse:6.46450
# [154]	validation-rmse:6.46302
# [155]	validation-rmse:6.46315
# [156]	validation-rmse:6.46262
# [157]	validation-rmse:6.46224
# [158]	validation-rmse:6.46149
# [159]	validation-rmse:6.46031
# [160]	validation-rmse:6.45956
# [161]	validation-rmse:6.45885
# [162]	validation-rmse:6.45845
# [163]	validation-rmse:6.45749
# [164]	validation-rmse:6.45750
# [165]	validation-rmse:6.45692
# [166]	validation-rmse:6.45658
# [167]	validation-rmse:6.45352
# [168]	validation-rmse:6.45274
# [169]	validation-rmse:6.45348
# [170]	validation-rmse:6.45293
# [171]	validation-rmse:6.45213
# [172]	validation-rmse:6.44809
# [173]	validation-rmse:6.44674
# [174]	validation-rmse:6.44561
# [175]	validation-rmse:6.44563
# [176]	validation-rmse:6.44459
# [177]	validation-rmse:6.44349
# [178]	validation-rmse:6.44339
# [179]	validation-rmse:6.44314
# [180]	validation-rmse:6.44172
# [181]	validation-rmse:6.44151
# [182]	validation-rmse:6.44064
# [183]	validation-rmse:6.43979
# [184]	validation-rmse:6.43961
# [185]	validation-rmse:6.43837
# [186]	validation-rmse:6.43759
# [187]	validation-rmse:6.43703
# [188]	validation-rmse:6.43566
# [189]	validation-rmse:6.43388
# [190]	validation-rmse:6.43293
# [191]	validation-rmse:6.43162
# [192]	validation-rmse:6.43148
# [193]	validation-rmse:6.43022
# [194]	validation-rmse:6.42916
# [195]	validation-rmse:6.42712
# [196]	validation-rmse:6.42690
# [197]	validation-rmse:6.42672
# [198]	validation-rmse:6.42565
# [199]	validation-rmse:6.42625
# [200]	validation-rmse:6.42684
# [201]	validation-rmse:6.42658
# [202]	validation-rmse:6.42543
# [203]	validation-rmse:6.42438
# [204]	validation-rmse:6.42378
# [205]	validation-rmse:6.42373
# [206]	validation-rmse:6.42295
# [207]	validation-rmse:6.42232
# [208]	validation-rmse:6.42184
# [209]	validation-rmse:6.42165
# [210]	validation-rmse:6.42133
# [211]	validation-rmse:6.42076
# [212]	validation-rmse:6.41982
# [213]	validation-rmse:6.41971
# [214]	validation-rmse:6.41942
# [215]	validation-rmse:6.41824
# [216]	validation-rmse:6.41734
# [217]	validation-rmse:6.41690
# [218]	validation-rmse:6.41671
# [219]	validation-rmse:6.41610
# [220]	validation-rmse:6.41546
# [221]	validation-rmse:6.41528
# [222]	validation-rmse:6.41452
# [223]	validation-rmse:6.41483
# [224]	validation-rmse:6.41564
# [225]	validation-rmse:6.41486
# [226]	validation-rmse:6.41460
# [227]	validation-rmse:6.41418
# [228]	validation-rmse:6.41413
# [229]	validation-rmse:6.41482
# [230]	validation-rmse:6.41469
# [231]	validation-rmse:6.41372
# [232]	validation-rmse:6.41334
# [233]	validation-rmse:6.41329
# [234]	validation-rmse:6.41325
# [235]	validation-rmse:6.41291
# [236]	validation-rmse:6.41247
# [237]	validation-rmse:6.41189
# [238]	validation-rmse:6.41130
# [239]	validation-rmse:6.41048
# [240]	validation-rmse:6.41064
# [241]	validation-rmse:6.41065
# [242]	validation-rmse:6.41032
# [243]	validation-rmse:6.40936
# [244]	validation-rmse:6.40845
# [245]	validation-rmse:6.40771
# [246]	validation-rmse:6.40578
# [247]	validation-rmse:6.40572
# [248]	validation-rmse:6.40435
# [249]	validation-rmse:6.40430
# [250]	validation-rmse:6.40434
# [251]	validation-rmse:6.40383
# [252]	validation-rmse:6.40349
# [253]	validation-rmse:6.40275
# [254]	validation-rmse:6.40279
# [255]	validation-rmse:6.40216
# [256]	validation-rmse:6.40087
# [257]	validation-rmse:6.40025
# [258]	validation-rmse:6.40036
# [259]	validation-rmse:6.39968
# [260]	validation-rmse:6.40014
# [261]	validation-rmse:6.39981
# [262]	validation-rmse:6.39926
# [263]	validation-rmse:6.39929
# [264]	validation-rmse:6.39831
# [265]	validation-rmse:6.39782
# [266]	validation-rmse:6.39678
# [267]	validation-rmse:6.39614
# [268]	validation-rmse:6.39679
# [269]	validation-rmse:6.39633
# [270]	validation-rmse:6.39551
# [271]	validation-rmse:6.39535
# [272]	validation-rmse:6.39501
# [273]	validation-rmse:6.39443
# [274]	validation-rmse:6.39396
# [275]	validation-rmse:6.39323
# [276]	validation-rmse:6.39320
# [277]	validation-rmse:6.39258
# [278]	validation-rmse:6.39249
# [279]	validation-rmse:6.39174
# [280]	validation-rmse:6.39111
# [281]	validation-rmse:6.39013
# [282]	validation-rmse:6.38828
# [283]	validation-rmse:6.38802
# [284]	validation-rmse:6.38746
# [285]	validation-rmse:6.38800
# [286]	validation-rmse:6.38772
# [287]	validation-rmse:6.38718
# [288]	validation-rmse:6.38529
# [289]	validation-rmse:6.38483
# [290]	validation-rmse:6.38504
# [291]	validation-rmse:6.38461
# [292]	validation-rmse:6.38409
# [293]	validation-rmse:6.38309
# [294]	validation-rmse:6.38312
# [295]	validation-rmse:6.38285
# [296]	validation-rmse:6.38407
# [297]	validation-rmse:6.38392
# [298]	validation-rmse:6.38404
# [299]	validation-rmse:6.38369
# [300]	validation-rmse:6.38281
# [301]	validation-rmse:6.38265
# [302]	validation-rmse:6.38239
# [303]	validation-rmse:6.38227
# [304]	validation-rmse:6.38198
# [305]	validation-rmse:6.38148
# [306]	validation-rmse:6.38140
# [307]	validation-rmse:6.38094
# [308]	validation-rmse:6.38071
# [309]	validation-rmse:6.38109
# [310]	validation-rmse:6.38165
# [311]	validation-rmse:6.38122
# [312]	validation-rmse:6.38069
# [313]	validation-rmse:6.38055
# [314]	validation-rmse:6.38030
# [315]	validation-rmse:6.38022
# [316]	validation-rmse:6.38018
# [317]	validation-rmse:6.37964
# [318]	validation-rmse:6.37950
# [319]	validation-rmse:6.37922
# [320]	validation-rmse:6.37718
# [321]	validation-rmse:6.37812
# [322]	validation-rmse:6.37782
# [323]	validation-rmse:6.37778
# [324]	validation-rmse:6.37759
# [325]	validation-rmse:6.37735
# [326]	validation-rmse:6.37679
# [327]	validation-rmse:6.37654
# [328]	validation-rmse:6.37616
# [329]	validation-rmse:6.37561
# [330]	validation-rmse:6.37547
# [331]	validation-rmse:6.37594
# [332]	validation-rmse:6.37614
# [333]	validation-rmse:6.37547
# [334]	validation-rmse:6.37588
# [335]	validation-rmse:6.37537
# [336]	validation-rmse:6.37433
# [337]	validation-rmse:6.37384
# [338]	validation-rmse:6.37303
# [339]	validation-rmse:6.37267
# [340]	validation-rmse:6.37251
# [341]	validation-rmse:6.37241
# [342]	validation-rmse:6.37241
# [343]	validation-rmse:6.37226
# [344]	validation-rmse:6.37162
# [345]	validation-rmse:6.37128
# [346]	validation-rmse:6.37133
# [347]	validation-rmse:6.37418
# [348]	validation-rmse:6.37379
# [349]	validation-rmse:6.37336
# [350]	validation-rmse:6.37306
# [351]	validation-rmse:6.37241
# [352]	validation-rmse:6.37191
# [353]	validation-rmse:6.37117
# [354]	validation-rmse:6.37032
# [355]	validation-rmse:6.37038
# [356]	validation-rmse:6.36992
# [357]	validation-rmse:6.36950
# [358]	validation-rmse:6.36912
# [359]	validation-rmse:6.36947
# [360]	validation-rmse:6.36946
# [361]	validation-rmse:6.36844
# [362]	validation-rmse:6.36905
# [363]	validation-rmse:6.36905
# [364]	validation-rmse:6.36876
# [365]	validation-rmse:6.36846
# [366]	validation-rmse:6.36765
# [367]	validation-rmse:6.36783
# [368]	validation-rmse:6.36884
# [369]	validation-rmse:6.36916
# [370]	validation-rmse:6.36831
# [371]	validation-rmse:6.36734
# [372]	validation-rmse:6.36746
# [373]	validation-rmse:6.36600
# [374]	validation-rmse:6.36605
# [375]	validation-rmse:6.36549
# [376]	validation-rmse:6.36545
# [377]	validation-rmse:6.36390
# [378]	validation-rmse:6.35929
# [379]	validation-rmse:6.35901
# [380]	validation-rmse:6.35839
# [381]	validation-rmse:6.35865
# [382]	validation-rmse:6.35771
# [383]	validation-rmse:6.35805
# [384]	validation-rmse:6.35897
# [385]	validation-rmse:6.35857
# [386]	validation-rmse:6.35842
# [387]	validation-rmse:6.35824
# [388]	validation-rmse:6.35790
# [389]	validation-rmse:6.35740
# [390]	validation-rmse:6.35561
# [391]	validation-rmse:6.35526
# [392]	validation-rmse:6.35525
# [393]	validation-rmse:6.35480
# [394]	validation-rmse:6.35498
# [395]	validation-rmse:6.35504
# [396]	validation-rmse:6.35474
# [397]	validation-rmse:6.35413
# [398]	validation-rmse:6.35434
# [399]	validation-rmse:6.35447
# [400]	validation-rmse:6.35450
# [401]	validation-rmse:6.35392
# [402]	validation-rmse:6.35343
# [403]	validation-rmse:6.35421
# [404]	validation-rmse:6.35362
# [405]	validation-rmse:6.35381
# [406]	validation-rmse:6.35427
# [407]	validation-rmse:6.35410
# [408]	validation-rmse:6.35331
# [409]	validation-rmse:6.35314
# [410]	validation-rmse:6.35337
# [411]	validation-rmse:6.35346
# [412]	validation-rmse:6.35308
# [413]	validation-rmse:6.35257
# [414]	validation-rmse:6.35258
# [415]	validation-rmse:6.35223
# [416]	validation-rmse:6.35148
# [417]	validation-rmse:6.35101
# [418]	validation-rmse:6.35048
# [419]	validation-rmse:6.35025
# [420]	validation-rmse:6.35011
# [421]	validation-rmse:6.34937
# [422]	validation-rmse:6.34949
# [423]	validation-rmse:6.35000
# [424]	validation-rmse:6.35018
# [425]	validation-rmse:6.34934
# [426]	validation-rmse:6.34897
# [427]	validation-rmse:6.34912
# [428]	validation-rmse:6.34872
# [429]	validation-rmse:6.34890
# [430]	validation-rmse:6.34842
# [431]	validation-rmse:6.34812
# [432]	validation-rmse:6.34740
# [433]	validation-rmse:6.34703
# [434]	validation-rmse:6.34700
# [435]	validation-rmse:6.34670
# [436]	validation-rmse:6.34645
# [437]	validation-rmse:6.34620
# [438]	validation-rmse:6.34586
# [439]	validation-rmse:6.34541
# [440]	validation-rmse:6.34442
# [441]	validation-rmse:6.34384
# [442]	validation-rmse:6.34370
# [443]	validation-rmse:6.34328
# [444]	validation-rmse:6.34315
# [445]	validation-rmse:6.34282
# [446]	validation-rmse:6.34279
# [447]	validation-rmse:6.34291
# [448]	validation-rmse:6.34040
# [449]	validation-rmse:6.34061
# [450]	validation-rmse:6.34133
# [451]	validation-rmse:6.34148
# [452]	validation-rmse:6.34129
# [453]	validation-rmse:6.34128
# [454]	validation-rmse:6.34191
# [455]	validation-rmse:6.34230
# [456]	validation-rmse:6.34232
# [457]	validation-rmse:6.34269
# [458]	validation-rmse:6.34265
# [459]	validation-rmse:6.34204
# [460]	validation-rmse:6.34212
# [461]	validation-rmse:6.34178
# [462]	validation-rmse:6.34196
# [463]	validation-rmse:6.34153
# [464]	validation-rmse:6.34104
# [465]	validation-rmse:6.34092
# [466]	validation-rmse:6.34038
# [467]	validation-rmse:6.34024
# [468]	validation-rmse:6.34002
# [469]	validation-rmse:6.34007
# [470]	validation-rmse:6.33992
# [471]	validation-rmse:6.34018
# [472]	validation-rmse:6.33950
# [473]	validation-rmse:6.33974
# [474]	validation-rmse:6.34010
# [475]	validation-rmse:6.33926
# [476]	validation-rmse:6.33909
# [477]	validation-rmse:6.33905
# [478]	validation-rmse:6.33903
# [479]	validation-rmse:6.33924
# [480]	validation-rmse:6.33893
# [481]	validation-rmse:6.33890
# [482]	validation-rmse:6.33891
# [483]	validation-rmse:6.33881
# [484]	validation-rmse:6.33854
# [485]	validation-rmse:6.33862
# [486]	validation-rmse:6.33811
# [487]	validation-rmse:6.33793
# [488]	validation-rmse:6.33783
# [489]	validation-rmse:6.33799
# [490]	validation-rmse:6.33679
# [491]	validation-rmse:6.33648
# [492]	validation-rmse:6.33719
# [493]	validation-rmse:6.33717
# [494]	validation-rmse:6.33739
# [495]	validation-rmse:6.33789
# [496]	validation-rmse:6.33825
# [497]	validation-rmse:6.33852
# [498]	validation-rmse:6.33845
# [499]	validation-rmse:6.33829
# [500]	validation-rmse:6.33829
# ...
# [340]	validation-rmse:6.41533
# [341]	validation-rmse:6.41533
# [14:30:09] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.04767
# [1]	validation-rmse:12.62269
# [2]	validation-rmse:10.35953
# [3]	validation-rmse:8.91442
# [4]	validation-rmse:8.01093
# [5]	validation-rmse:7.46192
# [6]	validation-rmse:7.12539
# [7]	validation-rmse:6.92655
# [8]	validation-rmse:6.79466
# [9]	validation-rmse:6.70736
# [10]	validation-rmse:6.65389
# [11]	validation-rmse:6.61994
# [12]	validation-rmse:6.59085
# [13]	validation-rmse:6.57117
# [14]	validation-rmse:6.55715
# [15]	validation-rmse:6.54826
# [16]	validation-rmse:6.54008
# [17]	validation-rmse:6.53299
# [18]	validation-rmse:6.52596
# [19]	validation-rmse:6.52103
# [20]	validation-rmse:6.51652
# [21]	validation-rmse:6.51328
# [22]	validation-rmse:6.51043
# [23]	validation-rmse:6.50827
# [24]	validation-rmse:6.50584
# [25]	validation-rmse:6.50398
# [26]	validation-rmse:6.50243
# [27]	validation-rmse:6.50013
# [28]	validation-rmse:6.49736
# [29]	validation-rmse:6.49644
# [30]	validation-rmse:6.49559
# [31]	validation-rmse:6.49526
# [32]	validation-rmse:6.49371
# [33]	validation-rmse:6.49213
# [34]	validation-rmse:6.49162
# [35]	validation-rmse:6.48973
# [36]	validation-rmse:6.48720
# [37]	validation-rmse:6.48645
# [38]	validation-rmse:6.48603
# [39]	validation-rmse:6.48464
# [40]	validation-rmse:6.48385
# [41]	validation-rmse:6.48293
# [42]	validation-rmse:6.48200
# [43]	validation-rmse:6.48094
# [44]	validation-rmse:6.48012
# [45]	validation-rmse:6.47914
# [46]	validation-rmse:6.47811
# [47]	validation-rmse:6.47823
# [48]	validation-rmse:6.47734
# [49]	validation-rmse:6.47648
# [50]	validation-rmse:6.47475
# [51]	validation-rmse:6.47425
# [52]	validation-rmse:6.47405
# [53]	validation-rmse:6.47412
# [54]	validation-rmse:6.47351
# [55]	validation-rmse:6.47282
# [56]	validation-rmse:6.47211
# [57]	validation-rmse:6.47165
# [58]	validation-rmse:6.47124
# [59]	validation-rmse:6.47170
# [60]	validation-rmse:6.47148
# [61]	validation-rmse:6.47101
# [62]	validation-rmse:6.47120
# [63]	validation-rmse:6.47154
# [64]	validation-rmse:6.47058
# [65]	validation-rmse:6.47014
# [66]	validation-rmse:6.47054
# [67]	validation-rmse:6.46965
# [68]	validation-rmse:6.46923
# [69]	validation-rmse:6.46947
# [70]	validation-rmse:6.46936
# [71]	validation-rmse:6.46879
# [72]	validation-rmse:6.46772
# [73]	validation-rmse:6.46767
# [74]	validation-rmse:6.46716
# [75]	validation-rmse:6.46657
# [76]	validation-rmse:6.46581
# [77]	validation-rmse:6.46586
# [78]	validation-rmse:6.46591
# [79]	validation-rmse:6.46514
# [80]	validation-rmse:6.46447
# [81]	validation-rmse:6.46461
# [82]	validation-rmse:6.46442
# [83]	validation-rmse:6.46397
# [84]	validation-rmse:6.46358
# [85]	validation-rmse:6.46398
# [86]	validation-rmse:6.46443
# [87]	validation-rmse:6.46457
# [88]	validation-rmse:6.46406
# [89]	validation-rmse:6.46418
# [90]	validation-rmse:6.46384
# [91]	validation-rmse:6.46185
# [92]	validation-rmse:6.46172
# [93]	validation-rmse:6.46158
# [94]	validation-rmse:6.46166
# [95]	validation-rmse:6.46176
# [96]	validation-rmse:6.46123
# [97]	validation-rmse:6.46117
# [98]	validation-rmse:6.46071
# [99]	validation-rmse:6.46106
# [100]	validation-rmse:6.46124
# [101]	validation-rmse:6.46108
# [102]	validation-rmse:6.46104
# [103]	validation-rmse:6.46184
# [104]	validation-rmse:6.46179
# [105]	validation-rmse:6.46172
# [106]	validation-rmse:6.46236
# [107]	validation-rmse:6.46208
# [108]	validation-rmse:6.46185
# [109]	validation-rmse:6.46216
# [110]	validation-rmse:6.46175
# [111]	validation-rmse:6.46202
#  14%|█▌         | 7/50 [04:15<26:10, 36.52s/trial, best loss: 6.312209206521932]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 11>()
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/.local/lib/python3.8/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Input In [18], in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/.local/lib/python3.8/site-packages/xgboost/core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/.local/lib/python3.8/site-packages/xgboost/core.py:1733, in Booster.update(self, dtrain, iteration, fobj)
#    1730 self._validate_features(dtrain)
#    1732 if fobj is None:
# -> 1733     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1734                                             ctypes.c_int(iteration),
#    1735                                             dtrain.handle))
#    1736 else:
#    1737     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
X_train
# Out:
# <73908x13221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 147816 stored elements in Compressed Sparse Row format>

# %%
mlflow.xgboost.autolog(disable=True)

# %%
from xgboost import XGBRegressor

# %%
with mlflow.start_run():
    
#     train = xgb.DMatrix(X_train, label=y_train)
#     valid = xgb.DMatrix(X_val, label=y_val)
    mlflow.set_tag("user","Galileo")

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = XGBRegressor(
        params=best_params,
#         dtrain=train,
        num_boost_round=1000,
        evals=[(X_val, 'validation')],
#         early_stopping_rounds=50
    )
    booster.fit(X_train,y_train)

    y_pred = booster.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [16:59:12] WARNING: ../src/learner.cc:627:
# Parameters: { "evals", "num_boost_round", "params" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# /home/eniola/.local/lib/python3.8/site-packages/xgboost/sklearn.py:722: UserWarning: kwargs is not saved in Scikit-Learn meta.
#   warnings.warn(str(k) + ' is not saved in Scikit-Learn meta.', UserWarning)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /Users/cristian.martinez/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
import argparse
import os
import pickle

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
def load_pickle(filename: str):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)


def run(data_path):

    X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
    X_valid, y_valid = load_pickle(os.path.join(data_path, "valid.pkl"))

    rf = RandomForestRegressor(max_depth=10, random_state=0)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_valid)

    rmse = mean_squared_error(y_valid, y_pred, squared=False)


if __name__ == '__main__':

    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--data_path",
        default="./output",
        help="the location where the processed NYC taxi trip data was saved."
    )
    args = parser.parse_args()

    run(args.data_path)
